# %%
import viswaternet as vis
import matplotlib.pyplot as plt

model = vis.VisWNModel('OneDrive\\Documents\\GitHub\\viswaternet\\Examples\\Networks\\CTown.inp')

# %%
model.plot_discrete_links(parameter = 'velocity', value='max', discrete_legend_loc='lower left')

# %%
fig, ax = plt.subplots(2,2,figsize=(11,11))

ax[0][0].set_frame_on(False)
model.plot_discrete_links(ax=ax[0][0], parameter = 'velocity', value = 'max', unit='ft/s', 
                          discrete_legend_loc='upper left', base_legend_label_font_size=6, discrete_legend_title_font_size=10, discrete_legend_label_font_size=6, legend_decimal_places=2, 
                          include_pumps=True, include_valves=True, draw_tanks=True, draw_reservoirs=True, draw_pumps=True, draw_valves=True, draw_links=True, 
                          reservoir_size=50, tank_size=50, valve_size=50,pump_width=2, link_width=2, link_style='dotted', ) #if i set include pumps or include valves to false, what does that change?

ax[0][1].set_frame_on(False)
model.plot_discrete_links(ax=ax[0][1], parameter = 'flowrate', value = 'mean', num_intervals = 3, cmap = 'cool', 
                          legend_title = 'Average Flowrate [m^3/s]', discrete_legend_title_font_size=10, discrete_legend_label_font_size=6, discrete_legend_loc='upper left', discrete_legend_label_color='b', discrete_legend_title_color='b', 
                          base_legend_label_font_size=6, base_legend_label_color='b',
                          reservoir_size=50, tank_size=50, 
                          pump_arrows=True, pump_width=2, 
                          valve_element='link', valve_width=3, valve_line_style='-')

ax[1][0].set_frame_on(False)
model.plot_discrete_links(ax=ax[1][0], parameter = 'headloss', value=15, intervals='automatic', cmap = 'summer', 
                          legend_title='Headloss', base_legend_loc='lower left', base_legend_label_font_size=6, discrete_legend_loc='upper left', discrete_legend_label_font_size=6, discrete_legend_title_font_size=10, draw_legend_frame=True,
                          reservoir_size=200, reservoir_color = 'g', reservoir_shape = '*', reservoir_border_color = 'k', reservoir_border_width = 1, 
                          tank_size=50, tank_color = 'm', tank_shape = 's', tank_border_color = 'k', tank_border_width = 1, 
                          valve_element='node', valve_size=50, valve_color = 'r', valve_shape = 'D', valve_border_color = 'k', valve_border_width = 1, 
                          pump_color = 'c', pump_width=2, pump_line_style = 'dotted')

ax[1][1].set_frame_on(False)
model.plot_discrete_links(ax=ax[1][1], parameter = 'quality', value=10, unit='hr', cmap='cool', 
                          discrete_legend_title_color='r', discrete_legend_title_font_size=10, discrete_legend_label_font_size=6, discrete_legend_loc='upper left', base_legend_label_font_size=6, draw_legend_frame=False, 
                          reservoir_size=50, tank_size=50, valve_element='link', valve_width=3, valve_arrows=False, 
                          pump_element='node', pump_size=10, pump_shape='s', pump_color='g', pump_border_color='k', pump_border_width=1, 
                          draw_nodes=True, base_node_color='k', base_node_size=5)

# %%
model.plot_discrete_links?
# Out:
# Signature:
# model.plot_discrete_links(
#     ax=None,
#     num_intervals=5,
#     parameter=None,
#     element_list=None,
#     include_pumps=True,
#     include_valves=True,
#     value=None,
#     unit=None,
#     intervals='automatic',
#     link_width=None,
#     label_list=None,
#     color_list=None,
#     link_style='-',
#     link_arrows=False,
#     draw_tanks=True,
#     draw_reservoirs=True,
#     draw_pumps=True,
#     draw_valves=True,
#     draw_nodes=False,
#     draw_links=False,
#     cmap='autumn_r',
#     legend_title=None,
#     base_legend_loc='upper right',
#     discrete_legend_loc='lower right',
#     savefig=False,
#     save_name=None,
#     dpi='figure',
#     save_format='png',
#     disable_interval_deleting=True,
#     base_legend_label_font_size=15,
#     base_legend_label_color='k',
#     discrete_legend_label_font_size=15,
#     discrete_legend_label_color='k',
#     discrete_legend_title_font_size=17,
#     discrete_legend_title_color='k',
# ...
